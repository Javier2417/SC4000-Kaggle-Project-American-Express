# %%
# read csv
import pandas as pd
javier_submission = pd.read_csv('../Javier/submission_quickwin_meta_ensemble.csv')
my_submission = pd.read_csv('submission_dart_seed_ensemble.csv')

a = 0.5
b = 0.5

final_submission = pd.DataFrame({
    'customer_ID': my_submission['customer_ID'],
    'prediction': a * my_submission['prediction'] + b * javier_submission['prediction']
})

final_submission.to_csv('submission_mix.csv', index=False)
